# %% [markdown]
# ## Financial Crisis and Bank Regulation

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib as mpl
from matplotlib import rcParams as rc
import seaborn as sns
import scipy as sc
import patsy as pt

# %%
FTSE = yf.download('^FTSE', start='2020-02-01', end='2020-05-31') #FTSE100
FTSE['Index'] = FTSE['Adj Close']
FTSE['Log_return'] = np.log(FTSE.Index/FTSE.Index.shift(1))
GSPC = yf.download('^GSPC', start='2020-02-01', end='2020-05-31') #SP500 (Standard and Poor 500)
GSPC['Index'] = GSPC['Adj Close']
GSPC['Log_return'] = np.log(GSPC.Index/GSPC.Index.shift(1))
DOW = yf.download('^DJI', start='2020-02-01', end='2020-05-31') #DOW
DOW['Index'] = DOW['Adj Close']
DOW['Log_return'] = np.log(DOW.Index/DOW.Index.shift(1))
IXIC = yf.download('^IXIC', start='2020-02-01', end='2020-05-31') #NASDAQ Composite
IXIC['Index'] = IXIC['Adj Close']
IXIC['Log_return'] = np.log(IXIC.Index/IXIC.Index.shift(1))
GDAXI = yf.download('^GDAXI', start='2020-02-01', end='2020-05-31') #DAX Performance Index
GDAXI['Index'] = GDAXI['Adj Close']
GDAXI['Log_return'] = np.log(GDAXI.Index/GDAXI.Index.shift(1))
#FCHI = yf.download('FCHI', start='2020-02-01', end='2020-05-31') #CAC 40
N225 = yf.download('^N225', start='2020-02-01', end='2020-05-31') #Nikkei 225
N225['Index'] = N225['Adj Close']
N225['Log_return'] = np.log(N225.Index/N225.Index.shift(1))
HSI = yf.download('^HSI', start='2020-02-01', end='2020-05-31') #Hang Seng
HSI['Index'] = HSI['Adj Close']
HSI['Log_return'] = np.log(HSI.Index/HSI.Index.shift(1))
SSE = yf.download('000001.SS', start='2020-02-01', end='2020-05-31') #Shang Hai Stock Exchange Composite Index
SSE['Index'] = SSE['Adj Close']
SSE['Log_return'] = np.log(SSE.Index/SSE.Index.shift(1))
SZ = yf.download('399001.SZ', start='2020-02-01', end='2020-05-31') #Shenzhen Component
SZ['Index'] = SZ['Adj Close']
SZ['Log_return'] = np.log(SZ.Index/SZ.Index.shift(1))
AXJO = yf.download('^AXJO', start='2020-02-01', end='2020-05-31') #S&P/ASX 200
AXJO['Index'] = AXJO['Adj Close']
AXJO['Log_return'] = np.log(AXJO.Index/AXJO.Index.shift(1))
GSPTSE = yf.download('^GSPTSE', start='2020-02-01', end='2020-05-31') #S&P/TSX Composite index
GSPTSE['Index'] = GSPTSE['Adj Close']
GSPTSE['Log_return'] = np.log(GSPTSE.Index/GSPTSE.Index.shift(1))
JN0U = yf.download('^JN0U.JO', start='2020-02-01', end='2020-05-31') #Top 40 Net USD TRI Index
JN0U['Index'] = JN0U['Adj Close']
JN0U['Log_return'] = np.log(JN0U.Index/JN0U.Index.shift(1))
RUT = yf.download('^RUT', start='2020-02-01', end='2020-05-31') #Russell 2000
RUT['Index'] = RUT['Adj Close']
RUT['Log_return'] = np.log(RUT.Index/RUT.Index.shift(1))
VIX = yf.download('^VIX', start='2020-02-01', end='2020-05-31') #CBOE Volatility Index
VIX['Index'] = VIX['Adj Close']
VIX['Log_return'] = np.log(VIX.Index/VIX.Index.shift(1))
STOXX50E = yf.download('^STOXX50E', start='2020-02-01', end='2020-05-31') #ESTX 50 PR.EUR
STOXX50E['Index'] = STOXX50E['Adj Close']
STOXX50E['Log_return'] = np.log(STOXX50E.Index/STOXX50E.Index.shift(1))
N100 = yf.download('^N100', start='2020-02-01', end='2020-05-31') #Euronext 100 Index 
N100['Index'] = N100['Adj Close']
N100['Log_return'] = np.log(N100.Index/N100.Index.shift(1))
BFX = yf.download('^BFX', start='2020-02-01', end='2020-05-31') #BEL 20
BFX['Index'] = BFX['Adj Close']
BFX['Log_return'] = np.log(BFX.Index/BFX.Index.shift(1))
#IMOEX = yf.download('^IMOEX.ME', start='2020-02-01', end='2020-05-31') #MOEX Russia Index
NYA = yf.download('^NYA', start='2020-02-01', end='2020-05-31') #NYSE Composite (DJ)
NYA['Index'] = NYA['Adj Close']
NYA['Log_return'] = np.log(NYA.Index/NYA.Index.shift(1))
XAX = yf.download('^XAX', start='2020-02-01', end='2020-05-31') #NYSE AMEX Composite Index
XAX['Index'] = XAX['Adj Close']
XAX['Log_return'] = np.log(XAX.Index/XAX.Index.shift(1))
STI = yf.download('^STI', start='2020-02-01', end='2020-05-31') #STI INdex
STI['Index'] = STI['Adj Close']
STI['Log_return'] = np.log(STI.Index/STI.Index.shift(1))
AORD = yf.download('^AORD', start='2020-02-01', end='2020-05-31') #All Ordinaries
AORD['Index'] = AORD['Adj Close']
AORD['Log_return'] = np.log(AORD.Index/AORD.Index.shift(1))
BSESN = yf.download('^BSESN', start='2020-02-01', end='2020-05-31') #S&P BSE SENSEX
BSESN['Index'] = BSESN['Adj Close']
BSESN['Log_return'] = np.log(BSESN.Index/BSESN.Index.shift(1))
JKSE = yf.download('^JKSE', start='2020-02-01', end='2020-05-31') #Jakarta Composite Index
JKSE['Index'] = JKSE['Adj Close']
JKSE['Log_return'] = np.log(JKSE.Index/JKSE.Index.shift(1))
KLSE = yf.download('^KLSE', start='2020-02-01', end='2020-05-31') #FTSE Bursa Malaysia KLCI
KLSE['Index'] = KLSE['Adj Close']
KLSE['Log_return'] = np.log(KLSE.Index/KLSE.Index.shift(1))
NZ50 = yf.download('^NZ50', start='2020-02-01', end='2020-05-31') #S&P/NZX 50 Index Gross
NZ50['Index'] = NZ50['Adj Close']
NZ50['Log_return'] = np.log(NZ50.Index/NZ50.Index.shift(1))
KS11 = yf.download('^KS11', start='2020-02-01', end='2020-05-31') #KOSPI Composite Index
KS11['Index'] = KS11['Adj Close']
KS11['Log_return'] = np.log(KS11.Index/KS11.Index.shift(1))
TWII = yf.download('^TWII', start='2020-02-01', end='2020-05-31') #TSEC Weighted Index
TWII['Index'] = TWII['Adj Close']
TWII['Log_return'] = np.log(TWII.Index/TWII.Index.shift(1))
BVSP = yf.download('^BVSP', start='2020-02-01', end='2020-05-31') #IBOVESPA
BVSP['Index'] = BVSP['Adj Close']
BVSP['Log_return'] = np.log(BVSP.Index/BVSP.Index.shift(1))
MXX = yf.download('^MXX', start='2020-02-01', end='2020-05-31') #IPC Mexico
MXX['Index'] = MXX['Adj Close']
MXX['Log_return'] = np.log(MXX.Index/MXX.Index.shift(1))
#IPSA = yf.download('^IPSA', start='2020-02-01', end='2020-05-31') #S&P/CLX IPSA
MERV = yf.download('^MERV', start='2020-02-01', end='2020-05-31') #MERVAL
MERV['Index'] = MERV['Adj Close']
MERV['Log_return'] = np.log(MERV.Index/MERV.Index.shift(1))
TA125 = yf.download('^TA125.TA', start='2020-02-01', end='2020-05-31') #TA-125
TA125['Index'] = TA125['Adj Close']
TA125['Log_return'] = np.log(TA125.Index/TA125.Index.shift(1))
#CASE30 = yf.download('^CASE30', start='2020-02-01', end='2020-05-31') #EGX 30 Price Return Index
NSEI = yf.download('^NSEI', start='2020-02-01', end='2020-05-31') #NIFTY 50
NSEI['Index'] = NSEI['Adj Close']
NSEI['Log_return'] = np.log(NSEI.Index/NSEI.Index.shift(1))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
sns.set_theme(style="whitegrid")
sns.displot(dropna_hs.Log_return, kde=True, color = "lightcoral").set(title = "Log Return Distribution")

# %%
sns.color_palette()
figure(figsize=(16, 14), dpi=80)
plt.rcParams["figure.autolayout"] = True
#plt.legend(loc="upper right", frameon=True, fontsize=3)
#plt.legend(ncol=3)
sns.lineplot(data = FTSE, y = 'Log_return', x = 'Date', label = 'FTSE_Logreturn', alpha  = 0.5)
sns.lineplot(data = DOW, y = 'Log_return', x = 'Date', label = 'DOW_Logreturn', alpha  = 0.5)
sns.lineplot(data = GSPC, y = 'Log_return', x = 'Date', label = 'GSPC_Logreturn', alpha  = 0.5)
sns.lineplot(data = IXIC, y = 'Log_return', x = 'Date', label = 'IXIC_Logreturn', alpha  = 0.5)
sns.lineplot(data = GDAXI, y = 'Log_return', x = 'Date', label = 'GDAXI_Logreturn', alpha  = 0.5)
sns.lineplot(data = N225, y = 'Log_return', x = 'Date', label = 'N225_Logreturn', alpha  = 0.5)
sns.lineplot(data = HSI, y = 'Log_return', x = 'Date', label = 'HSI_Logreturn', alpha  = 0.5)
sns.lineplot(data = SSE, y = 'Log_return', x = 'Date', label = 'SSE_Logreturn', alpha  = 0.5)
sns.lineplot(data = SZ, y = 'Log_return', x = 'Date', label = 'SZ_Logreturn', alpha  = 0.5)
sns.lineplot(data = AXJO, y = 'Log_return', x = 'Date', label = 'AXJO_Logreturn', alpha  = 0.5)
sns.lineplot(data = GSPTSE, y = 'Log_return', x = 'Date', label = 'GSPTSE_Logreturn', alpha  = 0.5)
sns.lineplot(data = JN0U, y = 'Log_return', x = 'Date', label = 'JN0U_Logreturn', alpha  = 0.5)
sns.lineplot(data = RUT, y = 'Log_return', x = 'Date', label = 'RUT_Logreturn', alpha  = 0.5)
#sns.lineplot(data = VIX, y = 'Log_return', x = 'Date', label = 'VIX_Logreturn', alpha  = 0.5)
sns.lineplot(data = STOXX50E, y = 'Log_return', x = 'Date', label = 'STOXX50E_Logreturn', alpha  = 0.5)
sns.lineplot(data = N100, y = 'Log_return', x = 'Date', label = 'N100_Logreturn', alpha  = 0.5)
sns.lineplot(data = BFX, y = 'Log_return', x = 'Date', label = 'BFX_Logreturn', alpha  = 0.5)
sns.lineplot(data = NYA, y = 'Log_return', x = 'Date', label = 'NYA_Logreturn', alpha  = 0.5)
sns.lineplot(data = XAX, y = 'Log_return', x = 'Date', label = 'XAX_Logreturn', alpha  = 0.5)
sns.lineplot(data = STI, y = 'Log_return', x = 'Date', label = 'STI_Logreturn', alpha  = 0.5)
sns.lineplot(data = AORD, y = 'Log_return', x = 'Date', label = 'AORD_Logreturn', alpha  = 0.5)
sns.lineplot(data = BSESN, y = 'Log_return', x = 'Date', label = 'BSESN_Logreturn', alpha  = 0.5)
sns.lineplot(data = JKSE, y = 'Log_return', x = 'Date', label = 'JKSE_Logreturn', alpha  = 0.5)
sns.lineplot(data = KLSE, y = 'Log_return', x = 'Date', label = 'KLSE_Logreturn', alpha  = 0.5)
sns.lineplot(data = NZ50, y = 'Log_return', x = 'Date', label = 'NZ50_Logreturn', alpha  = 0.5)
sns.lineplot(data = KS11, y = 'Log_return', x = 'Date', label = 'KS11_Logreturn', alpha  = 0.5)
sns.lineplot(data = TWII, y = 'Log_return', x = 'Date', label = 'TWII_Logreturn', alpha  = 0.5)
sns.lineplot(data = BVSP, y = 'Log_return', x = 'Date', label = 'BVSP_Logreturn', alpha  = 0.5)
sns.lineplot(data = MXX, y = 'Log_return', x = 'Date', label = 'MXX_Logreturn', alpha  = 0.5)
sns.lineplot(data = MERV, y = 'Log_return', x = 'Date', label = 'MERV_Logreturn', alpha  = 0.5)
sns.lineplot(data = TA125, y = 'Log_return', x = 'Date', label = 'TA125_Logreturn', alpha  = 0.5)
sns.lineplot(data = NSEI, y = 'Log_return', x = 'Date', label = 'NSEI_Logreturn', alpha  = 0.5)

#sns.set_title("Logarithm Return of World's Major Indices")
plt.savefig("Logret_COVID.jpeg")

# %%
figure(figsize=(16, 14), dpi=80)
plt.rcParams["figure.autolayout"] = True
sns.lineplot(data = VIX, y = 'Log_return', x = 'Date', label = 'VIX_Logreturn', alpha  = 0.5, color = "red")
plt.savefig("CBOE_VIX_COVID.jpeg")
